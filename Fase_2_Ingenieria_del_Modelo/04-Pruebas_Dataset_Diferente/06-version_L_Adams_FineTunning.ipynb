# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt

# Para que las imágenes salgan dentro del notebook (normalmente ya es así)
# %matplotlib inline

# %%
# Rutas
model = YOLO(r"C:\Users\GARI\Documents\IPYNB\PRUEBAS_MODELO_YOLOV8\07-prueba_data_1024_yolov8L_ADAMS_LR_FINE_T_VF\yolov8l_1024_precision_finetune_finalAdamW2\weights\best.pt")
#img_path = r"C:\Users\GARI\Documents\DATASETS\m1-only-src\images\DJI_0438.jpg" # DJI_0343
# img_path = r"C:\Users\GARI\Documents\DATASETS\m1-only-src\images\DJI_0343.jpg" # DJI_0343
img_path = r"C:\Users\GARI\Downloads\DJI_0343.JPG" # DJI_0343
# Inferencia (sin imprimir texto extra)
results = model(img_path, verbose=False)

# %%
# Descargas\DJI_0586.JPG

# %%
# Conteo
num_arboles = len(results[0].boxes)
print("Yolov8l-Árboles detectados:", num_arboles)

# Imagen anotada con las cajas de YOLO
annotated = results[0].plot()   # OJO: sin show=True

# Mostrar dentro del notebook
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
plt.axis("off")
# Out:
# Yolov8l-Árboles detectados: 36
# (-0.5, 2800.5, 1826.5, -0.5)

# %%
# AQUÍ CAMBIAS EL TÍTULO
plt.title(f"Yolov8L - Número de árboles detectados: {num_arboles}", fontsize=18)
plt.show()
