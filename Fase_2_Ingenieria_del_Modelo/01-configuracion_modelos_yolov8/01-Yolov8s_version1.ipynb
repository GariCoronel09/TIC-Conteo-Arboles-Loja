# %%
# PASO 1.1 — Montar Drive y LISTAR .zip
from google.colab import drive
drive.mount('/content/drive')

import os, glob

# Ajusta si usas otra carpeta
CANDIDATE_DIRS = [
    "/content/drive/MyDrive/DATASETS/dataset_640_resolucion",
    "/content/drive/MyDrive/Colab Notebooks/DATASETS/dataset_640_resolucion",
]
# Out:
# Mounted at /content/drive

# %%
BASE_DIR = None
for d in CANDIDATE_DIRS:
    if os.path.isdir(d):
        BASE_DIR = d
        break

if BASE_DIR is None:
    print("❌ No encontré la carpeta del dataset en las rutas esperadas.")
    print("Indícame la ruta exacta. Contenido de /content/drive/MyDrive:")
    for item in sorted(os.listdir("/content/drive/MyDrive")):
        print(" -", item)
else:
    print("✅ Carpeta localizada en:", BASE_DIR)
    zips = sorted(glob.glob(os.path.join(BASE_DIR, "*.zip")))
    if not zips:
        print("❌ No hay .zip en esa carpeta.")
    else:
        print("ZIPs encontrados:")
        for z in zips:
            print(" -", os.path.basename(z))
        v1 = [z for z in zips if "v1" in os.path.basename(z).lower()]
        SELECTED_ZIP = v1[0] if v1 else zips[0]
        print("\n➡️  Seleccionado para el PASO 1.2:", os.path.basename(SELECTED_ZIP))
# Out:
# ✅ Carpeta localizada en: /content/drive/MyDrive/Colab Notebooks/DATASETS/dataset_640_resolucion
# ZIPs encontrados:
#  - arboles_data_v1.zip
#  - arboles_data_v2.zip
#
# ➡️  Seleccionado para el PASO 1.2: arboles_data_v1.zip

# %% [markdown]
# PASO 1.2 — Copiar y descomprimir el ZIP v1

# %%
# PASO 1.2 — Copiar y descomprimir el ZIP v1 en /content
import os, shutil, zipfile

# Usa la misma variable BASE_DIR del paso anterior
ZIP_V1 = None
for f in os.listdir(BASE_DIR):
    if "v1" in f.lower() and f.endswith(".zip"):
        ZIP_V1 = os.path.join(BASE_DIR, f)
        break

if ZIP_V1 is None:
    raise FileNotFoundError("No encontré un archivo con 'v1' en su nombre dentro de la carpeta del dataset.")

print("📦 Archivo v1 seleccionado:", os.path.basename(ZIP_V1))
# Out:
# 📦 Archivo v1 seleccionado: arboles_data_v1.zip

# %%
# Copiar al almacenamiento local de Colab (más rápido)
local_zip = "/content/dataset_v1.zip"
if os.path.exists(local_zip):
    os.remove(local_zip)
shutil.copy2(ZIP_V1, local_zip)
print("✅ Copiado a:", local_zip)
# Out:
# ✅ Copiado a: /content/dataset_v1.zip

# %%
# Descomprimir en carpeta limpia
extract_dir = "/content/dataset_yolov1"
if os.path.exists(extract_dir):
    shutil.rmtree(extract_dir)
os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(local_zip, "r") as zf:
    zf.extractall(extract_dir)

print("✅ Descomprimido en:", extract_dir)
print("\nContenido de primer nivel:")
for item in os.listdir(extract_dir):
    p = os.path.join(extract_dir, item)
    print(" - [DIR]" if os.path.isdir(p) else " - [FILE]", item)
# Out:
# ✅ Descomprimido en: /content/dataset_yolov1
#
# Contenido de primer nivel:
#  - [DIR] arboles_data_v1

# %% [markdown]
# PASO 2.1 — Detectar la raíz real del dataset descomprimido

# %%
# PASO 2.1 — Detectar la carpeta raíz del dataset descomprimido
import os

EXTRACT_DIR = "/content/dataset_yolov1"  # carpeta donde se descomprimió el ZIP

def pick_root(extract_dir):
    """Si solo hay una subcarpeta dentro, entrar en ella; si no, usar extract_dir."""
    items = [i for i in os.listdir(extract_dir) if not i.startswith(".")]
    if len(items) == 1 and os.path.isdir(os.path.join(extract_dir, items[0])):
        return os.path.join(extract_dir, items[0])
    return extract_dir

ROOT = pick_root(EXTRACT_DIR)

print("📁 Raíz detectada:", ROOT)
print("\nContenido dentro de la raíz:")
for i in os.listdir(ROOT):
    print(" -", i)
# Out:
# 📁 Raíz detectada: /content/dataset_yolov1/arboles_data_v1
#
# Contenido dentro de la raíz:
#  - data.yaml
#  - images
#  - labels

# %% [markdown]
# # PASO 2.2 — Buscar y leer data.yaml (si existe)

# %%
# PASO 2.2 — Buscar y leer data.yaml (si existe)
import os, glob, yaml

yaml_candidates = []
for pattern in ("*.yaml", "*.yml"):
    yaml_candidates += glob.glob(os.path.join(ROOT, pattern))

if not yaml_candidates:
    print("❌ No se encontró data.yaml ni data.yml en la raíz del dataset.")
else:
    print("✅ Archivos YAML encontrados:")
    for y in yaml_candidates:
        print(" -", os.path.basename(y))

    try:
        # Tomar preferentemente el que se llame data.yaml
        preferred = [y for y in yaml_candidates if "data" in os.path.basename(y).lower()]
        preferred = preferred[0] if preferred else yaml_candidates[0]
        print("\n📄 Leyendo:", os.path.basename(preferred))

        with open(preferred, "r", encoding="utf-8") as f:
            yaml_info = yaml.safe_load(f)

        print("\nContenido del YAML:\n")
        print(yaml_info)
    except Exception as e:
        print("⚠ Error al leer el YAML:", e)
# Out:
# ✅ Archivos YAML encontrados:
#  - data.yaml
#
# 📄 Leyendo: data.yaml
#
# Contenido del YAML:
#
# {'path': '/content/drive/MyDrive/Colab Notebooks/DATASETS/dataset_640_resolucion/', 'train': 'images/train', 'val': 'images/val', 'test': 'images/test', 'names': {0: 'arbol'}}

# %% [markdown]
# # PASO 2.4 — Conteo de imágenes y etiquetas por split

# %%
# PASO 2.4 — Conteo de imágenes y etiquetas por split
import os

def count_files(img_dir, lbl_dir):
    imgs = [f for f in os.listdir(img_dir) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
    lbls = [f for f in os.listdir(lbl_dir) if f.lower().endswith('.txt')]
    print(f"  🖼️  Imágenes: {len(imgs)}  |  🏷️  Etiquetas: {len(lbls)}")
    if len(imgs) != len(lbls):
        print("  ⚠️  Diferencia detectada entre número de imágenes y etiquetas.")
        # Mostrar ejemplos de archivos sin pareja
        stem_imgs = {os.path.splitext(f)[0] for f in imgs}
        stem_lbls = {os.path.splitext(f)[0] for f in lbls}
        solo_imgs = sorted(list(stem_imgs - stem_lbls))[:5]
        solo_lbls = sorted(list(stem_lbls - stem_imgs))[:5]
        if solo_imgs:
            print("   - Faltan etiquetas para:", solo_imgs)
        if solo_lbls:
            print("   - Faltan imágenes para:", solo_lbls)
    return len(imgs), len(lbls)

if 'paths' in globals() and paths:
    print("\n=== 📊 RESUMEN POR SPLIT ===")
    for s, d in paths.items():
        print(f"\n[{s.upper()}]")
        if os.path.isdir(d["images"]) and os.path.isdir(d["labels"]):
            count_files(d["images"], d["labels"])
        else:
            print("  ❌ Falta carpeta:", d)
else:
    print("❌ No se detectaron rutas válidas en el paso anterior (2.3).")
# Out:
# === 📊 RESUMEN POR SPLIT ===
#
# [TRAIN]
#   🖼️  Imágenes: 11200  |  🏷️  Etiquetas: 11200
#
# [VAL]
#   🖼️  Imágenes: 3200  |  🏷️  Etiquetas: 3200
#
# [TEST]
#   🖼️  Imágenes: 1600  |  🏷️  Etiquetas: 1600

# %%
# PASO 3.1 — Instalar y verificar YOLOv8 (Ultralytics)
# !pip install ultralytics --upgrade --quiet

from ultralytics import YOLO
import ultralytics

print("✅ Ultralytics instalado correctamente.")
print("Versión:", ultralytics.__version__)

# Verificar GPU disponible
import torch
print("GPU detectada:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "❌ No hay GPU activa")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.1 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ Ultralytics instalado correctamente.
# Versión: 8.3.221
# GPU detectada: NVIDIA A100-SXM4-40GB

# %% [markdown]
# ### observar bien el yaml con la ruta si se crea

# %%
# PASO 3.2 — Crear / Ajustar archivo data.yaml
import os, yaml

yaml_path = os.path.join(ROOT, "data.yaml")

# Rutas relativas desde la raíz del dataset
train_path = os.path.relpath(paths["train"]["images"], ROOT)
val_path   = os.path.relpath(paths["val"]["images"], ROOT)
test_path  = os.path.relpath(paths["test"]["images"], ROOT)

# Definir las clases (ajusta si tienes más de una)
data_config = {
    "path": ROOT,
    "train": train_path,
    "val": val_path,
    "test": test_path,
    "names": ["arbol"],  # puedes añadir más clases aquí
}

with open(yaml_path, "w", encoding="utf-8") as f:
    yaml.dump(data_config, f, sort_keys=False, allow_unicode=True)

print("✅ Archivo data.yaml creado correctamente en:", yaml_path)
print("\nContenido del data.yaml:\n")
print(yaml.dump(data_config, sort_keys=False, allow_unicode=True))
# Out:
# ✅ Archivo data.yaml creado correctamente en: /content/dataset_yolov1/arboles_data_v1/data.yaml
#
# Contenido del data.yaml:
#
# path: /content/dataset_yolov1/arboles_data_v1
# train: images/train
# val: images/val
# test: images/test
# names:
# - tree
# nc: 1

# %%
# PASO 3.3b — Entrenar YOLOv8s guardando best.pt y plots
from ultralytics import YOLO
import os

# YAML creado en el paso 3.2
yaml_path = os.path.join(ROOT, "data.yaml")

# Crea el modelo (parte de pesos preentrenados)
model = YOLO("yolov8s.pt")

results = model.train(
    data=yaml_path,
    epochs=80,           # 50 si quieres más rápido; 80 para mayor estabilidad
    imgsz=640,
    batch=16,            # si aparece OOM, baja a 8
    device=0,            # usar GPU
    workers=4,
    seed=42,
    project="/content/runs",
    name="yolov8s_v1_precision",

    # Calidad/estabilidad
    cos_lr=True,         # scheduler coseno
    patience=20,         # early stop si no mejora

    # Guardados y visualizaciones
    save=True,
    save_period=10,      # checkpoint cada 10 épocas
    plots=True,          # genera PR, F1, confusión, etc.
    val=True,

    # Rendimiento (tienes 83GB RAM)
    cache=True,          # cachea imágenes en RAM para acelerar el dataloader
    close_mosaic=10      # cierra mosaic en las últimas 10 épocas
)

print("\n✅ Entrenamiento lanzado/finalizado.")
print("Carpeta de resultados:", results.save_dir)
print("Pesos mejores (best.pt):", os.path.join(str(results.save_dir), "weights", "best.pt"))
print("Últimos pesos (last.pt):", os.path.join(str(results.save_dir), "weights", "last.pt"))
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 171.9MB/s 0.1s
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/content/dataset_yolov1/arboles_data_v1/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=80, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8s_v1_precision, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/yolov8s_v1_precision, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.6MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 129 layers, 11,135,987 parameters, 11,135,971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 65.9MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3569.8±542.1 MB/s, size: 463.9 KB)
# train: Scanning /content/dataset_yolov1/arboles_data_v1/labels/train... 11200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 11200/11200 340.7it/s 32.9s
# train: New cache created: /content/dataset_yolov1/arboles_data_v1/labels/train.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (12.8GB RAM): 100% ━━━━━━━━━━━━ 11200/11200 408.4it/s 27.4s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2205.0±1816.0 MB/s, size: 442.8 KB)
# val: Scanning /content/dataset_yolov1/arboles_data_v1/labels/val... 3200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3200/3200 327.3it/s 9.8s
# val: New cache created: /content/dataset_yolov1/arboles_data_v1/labels/val.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (3.7GB RAM): 100% ━━━━━━━━━━━━ 3200/3200 414.6it/s 7.7s
# Plotting labels to /content/runs/yolov8s_v1_precision/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /content/runs/yolov8s_v1_precision
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80       3.6G      2.218      2.455      1.993        169        640: 100% ━━━━━━━━━━━━ 700/700 10.6it/s 1:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 6.8it/s 14.7s
#                    all       3200      21460      0.402      0.345      0.313      0.107
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      4.38G       2.07       2.13      1.784        146        640: 100% ━━━━━━━━━━━━ 700/700 11.5it/s 1:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.0it/s 14.3s
#                    all       3200      21460      0.382      0.352        0.3      0.096
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80       4.4G      2.079      2.145      1.792        159        640: 100% ━━━━━━━━━━━━ 700/700 11.7it/s 59.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.2it/s 13.8s
#                    all       3200      21460      0.387      0.346      0.294      0.101
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      4.43G      2.094      2.153      1.806        145        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.2it/s 13.8s
#                    all       3200      21460      0.415       0.37      0.329      0.112
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      4.45G      2.072      2.101      1.787        184        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.3it/s 13.7s
#                    all       3200      21460       0.46      0.384      0.364      0.124
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      4.48G      2.056      2.081      1.775        141        640: 100% ━━━━━━━━━━━━ 700/700 11.8it/s 59.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.6it/s 13.2s
#                    all       3200      21460      0.481      0.398      0.391      0.142
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80       4.5G      2.047      2.047       1.77         99        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.3it/s 13.7s
#                    all       3200      21460      0.461      0.401      0.383      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      4.52G      2.031      2.026      1.753        145        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.3it/s 13.6s
#                    all       3200      21460      0.454      0.411      0.398      0.146
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      4.55G      2.024      2.007      1.748        183        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.5it/s 13.4s
#                    all       3200      21460      0.487      0.405      0.403      0.148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      4.57G      2.022      1.986      1.742        166        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.1it/s 14.0s
#                    all       3200      21460      0.495      0.418      0.414      0.148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80       4.6G      2.006      1.976      1.743        157        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.4it/s 13.5s
#                    all       3200      21460      0.521      0.433      0.444      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      4.62G      2.003      1.962      1.731        123        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.3it/s 13.6s
#                    all       3200      21460      0.519      0.444      0.451      0.167
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      4.65G      1.994      1.941      1.724        191        640: 100% ━━━━━━━━━━━━ 700/700 11.8it/s 59.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.4it/s 13.4s
#                    all       3200      21460      0.516      0.442      0.456      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      4.67G      1.991      1.923      1.721        177        640: 100% ━━━━━━━━━━━━ 700/700 11.8it/s 59.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.4it/s 13.4s
#                    all       3200      21460      0.522      0.445      0.454      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80       4.7G      1.987      1.917      1.725        185        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.3it/s 13.6s
#                    all       3200      21460       0.52      0.449      0.459      0.169
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      4.72G      1.982      1.902      1.714        139        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.5it/s 13.4s
#                    all       3200      21460      0.547      0.447      0.472      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      4.74G      1.973      1.891      1.717        139        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.6it/s 13.2s
#                    all       3200      21460      0.551      0.459       0.48      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      4.77G      1.973      1.882      1.707        135        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.5it/s 13.3s
#                    all       3200      21460       0.55      0.464      0.484      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      4.79G      1.968      1.872      1.702        167        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.4it/s 13.5s
#                    all       3200      21460      0.542      0.474      0.485       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80      4.82G      1.964      1.853      1.705        158        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.4it/s 13.6s
#                    all       3200      21460      0.564      0.477      0.498      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      4.84G      1.953      1.845      1.696        179        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.5it/s 13.4s
#                    all       3200      21460      0.549      0.472      0.487      0.183
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80      4.87G      1.951      1.832      1.696        160        640: 100% ━━━━━━━━━━━━ 700/700 11.8it/s 59.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.5it/s 13.4s
#                    all       3200      21460      0.564      0.484      0.504       0.19
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80      4.89G      1.949      1.814       1.68        122        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 59.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.6it/s 13.1s
#                    all       3200      21460      0.559      0.485      0.506      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80      4.91G      1.941      1.792      1.674        192        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.4it/s 13.6s
#                    all       3200      21460      0.569      0.493      0.513      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80      4.94G      1.948      1.791      1.668        144        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.3it/s 13.7s
#                    all       3200      21460      0.563      0.498      0.517      0.195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      4.96G      1.937      1.777      1.671        164        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.5it/s 13.3s
#                    all       3200      21460      0.572        0.5      0.521      0.197
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      4.99G      1.933      1.763      1.667        161        640: 100% ━━━━━━━━━━━━ 700/700 11.8it/s 59.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.6it/s 13.1s
#                    all       3200      21460      0.557      0.502      0.516      0.196
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      5.01G      1.927       1.75      1.658        151        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.6it/s 13.2s
#                    all       3200      21460      0.566      0.504      0.524      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80      5.04G      1.919       1.74      1.651        157        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.6it/s 13.1s
#                    all       3200      21460       0.58      0.497      0.523        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80      5.06G      1.917      1.728      1.649        115        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.6it/s 13.1s
#                    all       3200      21460      0.579      0.512       0.53      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80      5.08G      1.912      1.717      1.648        183        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.5it/s 13.3s
#                    all       3200      21460      0.574      0.515      0.531      0.202
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80      5.11G      1.907      1.702      1.639        210        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.7it/s 13.1s
#                    all       3200      21460      0.582      0.508      0.531      0.203
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      5.13G      1.905      1.695      1.645        160        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.5it/s 13.2s
#                    all       3200      21460      0.579      0.519      0.536      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80      5.16G        1.9      1.678      1.638        190        640: 100% ━━━━━━━━━━━━ 700/700 11.8it/s 59.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.7it/s 13.0s
#                    all       3200      21460      0.586      0.515      0.539      0.207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80      5.18G      1.895      1.672      1.629        130        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.7it/s 13.0s
#                    all       3200      21460       0.58      0.525      0.543      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80      5.21G      1.885      1.653      1.624        196        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.6it/s 13.2s
#                    all       3200      21460      0.582      0.525      0.545      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      5.23G      1.889      1.645      1.628        165        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 59.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.5it/s 13.3s
#                    all       3200      21460      0.579       0.53      0.546      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80      5.25G       1.88      1.633      1.627        166        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.7it/s 13.0s
#                    all       3200      21460      0.589       0.53      0.549      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      5.28G      1.877      1.614      1.613        139        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.7it/s 13.0s
#                    all       3200      21460      0.583      0.535      0.552      0.212
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80       5.3G      1.869      1.598      1.607        126        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.7it/s 13.1s
#                    all       3200      21460      0.591      0.539      0.556      0.214
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      5.33G      1.866      1.592      1.605        185        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.6it/s 13.2s
#                    all       3200      21460      0.588       0.54      0.554      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80      5.35G      1.856       1.57      1.595        149        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.8it/s 12.9s
#                    all       3200      21460      0.584      0.547      0.555      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      5.38G       1.85      1.562      1.592        131        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.7it/s 13.0s
#                    all       3200      21460      0.592      0.541      0.563      0.217
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80       5.4G      1.845      1.546      1.586        136        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.6it/s 13.1s
#                    all       3200      21460      0.593       0.54      0.562      0.217
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      5.42G      1.839      1.534      1.583        126        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.7it/s 13.0s
#                    all       3200      21460      0.592      0.542      0.559      0.217
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      5.45G      1.834      1.519      1.579        206        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.8it/s 12.8s
#                    all       3200      21460      0.588      0.546      0.563      0.218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      5.47G      1.829       1.51      1.571        189        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.6it/s 13.2s
#                    all       3200      21460      0.586      0.551      0.566      0.218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      5.64G      1.823      1.492      1.563        178        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.7it/s 13.0s
#                    all       3200      21460      0.586      0.553      0.564      0.218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      5.66G      1.813      1.477       1.56        181        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.5it/s 13.3s
#                    all       3200      21460      0.585      0.554      0.563      0.218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      5.69G      1.808      1.475      1.555        163        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.7it/s 12.9s
#                    all       3200      21460      0.585      0.555      0.563      0.218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      5.71G      1.802      1.457      1.551        195        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.9it/s 12.7s
#                    all       3200      21460      0.586      0.555      0.565      0.218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      5.73G      1.797      1.441      1.544        104        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.9it/s 12.7s
#                    all       3200      21460      0.599       0.55      0.568      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80       5.9G      1.792       1.43      1.542        205        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 59.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.8it/s 12.8s
#                    all       3200      21460      0.595      0.557       0.57      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      5.93G      1.786      1.423      1.541        139        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.8it/s 12.9s
#                    all       3200      21460      0.589      0.561      0.568       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80      5.95G      1.772      1.404      1.526        117        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.8it/s 12.9s
#                    all       3200      21460      0.588      0.562      0.567      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      5.97G       1.77      1.395      1.526        211        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.9it/s 12.7s
#                    all       3200      21460      0.587      0.562      0.567      0.218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80         6G      1.763      1.385      1.519        132        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.8it/s 12.9s
#                    all       3200      21460      0.593      0.557      0.567      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      6.02G       1.76      1.377      1.519        134        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.9it/s 12.7s
#                    all       3200      21460      0.592      0.561      0.568       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      6.05G      1.748      1.361      1.507        161        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.8it/s 12.9s
#                    all       3200      21460      0.593      0.562      0.569       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      6.07G      1.747      1.354      1.511        169        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.8it/s 12.9s
#                    all       3200      21460      0.594      0.561      0.569       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80       6.1G      1.741      1.345      1.508        164        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.9it/s 12.7s
#                    all       3200      21460      0.595      0.562      0.569       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80      6.12G      1.734      1.331      1.495        172        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.9it/s 12.6s
#                    all       3200      21460      0.592      0.564      0.569      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80      6.24G      1.726      1.327      1.491        190        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.6it/s 13.2s
#                    all       3200      21460      0.591      0.566      0.569       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80      6.27G      1.724      1.315      1.484        147        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.6it/s 13.2s
#                    all       3200      21460      0.591      0.566      0.568       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80      6.29G      1.714      1.314      1.483        160        640: 100% ━━━━━━━━━━━━ 700/700 11.8it/s 59.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.9it/s 12.6s
#                    all       3200      21460      0.585      0.571      0.568      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/80      6.32G      1.714      1.301      1.479        146        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.9it/s 12.6s
#                    all       3200      21460      0.585      0.569      0.567      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/80      6.34G      1.707      1.298      1.479        134        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.8it/s 12.8s
#                    all       3200      21460      0.586      0.567      0.565      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/80      6.46G      1.704       1.29      1.473        192        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.8it/s 12.9s
#                    all       3200      21460      0.589      0.568      0.567      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/80      6.62G      1.698      1.285      1.472        118        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 8.0it/s 12.6s
#                    all       3200      21460      0.585      0.571      0.567      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/80      6.65G        1.7      1.284      1.474        166        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.9it/s 12.6s
#                    all       3200      21460      0.584      0.572      0.566      0.219
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/80      6.67G      1.725      1.256      1.513        100        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.8it/s 12.8s
#                    all       3200      21460      0.582      0.574      0.566      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/80       6.7G      1.705      1.229      1.505        130        640: 100% ━━━━━━━━━━━━ 700/700 11.9it/s 58.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.9it/s 12.6s
#                    all       3200      21460      0.583      0.573      0.566      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/80      6.72G        1.7      1.217      1.502         95        640: 100% ━━━━━━━━━━━━ 700/700 12.0it/s 58.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 7.9it/s 12.7s
#                    all       3200      21460      0.586       0.57      0.566      0.219
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 53, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 73 epochs completed in 1.479 hours.
# Optimizer stripped from /content/runs/yolov8s_v1_precision/weights/last.pt, 22.5MB
# Optimizer stripped from /content/runs/yolov8s_v1_precision/weights/best.pt, 22.5MB
#
# Validating /content/runs/yolov8s_v1_precision/weights/best.pt...
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 6.4it/s 15.7s
#                    all       3200      21460      0.596      0.556       0.57      0.221
# Speed: 0.1ms preprocess, 0.8ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /content/runs/yolov8s_v1_precision
#
# ✅ Entrenamiento lanzado/finalizado.
# Carpeta de resultados: /content/runs/yolov8s_v1_precision
# Pesos mejores (best.pt): /content/runs/yolov8s_v1_precision/weights/best.pt
# Últimos pesos (last.pt): /content/runs/yolov8s_v1_precision/weights/last.pt

# %%
from google.colab import drive
drive.mount('/content/drive')  # te pedirá autorización una sola vez
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r /content/runs/yolov8s_v1_precision /content/drive/MyDrive/yolov8_runs_backup/

# %% [markdown]
# ESTADOS DEL ENTRENAMIENTO

# %%
from IPython.display import Image, display
import pandas as pd
import os

# Ruta a tu copia en Drive
run_path = "/content/drive/MyDrive/yolov8_runs_backup"

# Mostrar las gráficas principales
display(Image(filename=os.path.join(run_path, "results.png")))
display(Image(filename=os.path.join(run_path, "confusion_matrix.png")))

# %%
import pandas as pd

csv_path = f"{run_path}/results.csv"
df = pd.read_csv(csv_path)

print("Columnas disponibles:", df.columns.tolist(), "\n")
print("Últimas métricas del entrenamiento:")
print(df.tail(3))  # últimas 3 filas (finales del entrenamiento)
# Out:
# Columnas disponibles: ['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss', 'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss', 'lr/pg0', 'lr/pg1', 'lr/pg2']
#
# Últimas métricas del entrenamiento:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 70     71  5179.17         1.72481         1.25632         1.51337
# 71     72  5251.07         1.70496         1.22944         1.50459
# 72     73  5322.79         1.69969         1.21732         1.50239
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 70               0.58242            0.57382           0.56594
# 71               0.58317            0.57325           0.56631
# 72               0.58556            0.57008           0.56592
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 70              0.21941       2.10393       1.48768       1.80067  0.000477
# 71              0.21882       2.10522       1.48698       1.80153  0.000406
# 72              0.21868       2.10734       1.48583       1.80312  0.000342
#
#       lr/pg1    lr/pg2
# 70  0.000477  0.000477
# 71  0.000406  0.000406
# 72  0.000342  0.000342

# %%
precision_final = df["metrics/precision(B)"].iloc[-1]
recall_final = df["metrics/recall(B)"].iloc[-1]
map50_final = df["metrics/mAP50(B)"].iloc[-1]
map95_final = df["metrics/mAP50-95(B)"].iloc[-1]

print(f"Precisión final: {precision_final:.3f}")
print(f"Recall final: {recall_final:.3f}")
print(f"mAP@50: {map50_final:.3f}")
print(f"mAP@50-95: {map95_final:.3f}")
# Out:
# Precisión final: 0.586
# Recall final: 0.570
# mAP@50: 0.566
# mAP@50-95: 0.219

# %%
### PRUEBAS

# %%
from ultralytics import YOLO

# Ruta al modelo que entrenaste
BEST_PT = "/content/runs/yolov8s_v1_precision/weights/best.pt"

# Cargar el modelo
model = YOLO(BEST_PT)
print("✅ Modelo cargado correctamente:", BEST_PT)
# Out:
# ✅ Modelo cargado correctamente: /content/runs/yolov8s_v1_precision/weights/best.pt

# %%
from PIL import Image
from IPython.display import display

# Ruta de una imagen de prueba (puedes cambiarla)
IMG_PATH = "/content/dataset_yolov1/arboles_data_v1/images/val/DJI_IMG_0070_05_05.png"

# Inferencia
results = model.predict(
    source=IMG_PATH,
    imgsz=640,     # o 1024 si tu dataset fue 1024x1024
    conf=0.25,     # umbral de confianza
    iou=0.45,      # supresión no máxima
    save=True,     # guarda la imagen anotada
    verbose=False
)

# Mostrar imagen anotada
r = results[0]
annotated = r.plot()[:, :, ::-1]  # BGR -> RGB
display(Image.fromarray(annotated))

# Conteo de detecciones
num_det = len(r.boxes) if r.boxes is not None else 0
print(f"🌿 Árboles detectados: {num_det}")

# Carpeta donde se guardó la imagen resultante
print("📁 Imagen anotada guardada en:", r.save_dir)
# Out:
# Results saved to /content/runs/detect/predict
# <PIL.Image.Image image mode=RGB size=640x640>
# 🌿 Árboles detectados: 8
# 📁 Imagen anotada guardada en: /content/runs/detect/predict
