# %% [markdown]
#  ### Entrenamiento del modelo Yolov8 version M

# %%
# PASO 1.1 — Montar Drive y LISTAR .zip
from google.colab import drive
drive.mount('/content/drive')

import os, glob

# Ajusta si usas otra carpeta
CANDIDATE_DIRS = [
    "/content/drive/MyDrive/DATASETS/dataset_1024_resolucion",
    "/content/drive/MyDrive/Colab Notebooks/DATASETS/dataset_1024_resolucion",
]
# Out:
# Mounted at /content/drive

# %%
BASE_DIR = None
for d in CANDIDATE_DIRS:
    if os.path.isdir(d):
        BASE_DIR = d
        break

if BASE_DIR is None:
    print("No encontré la carpeta del dataset en las rutas esperadas.")
    print("Indícame la ruta exacta. Contenido de /content/drive/MyDrive:")
    for item in sorted(os.listdir("/content/drive/MyDrive")):
        print(" -", item)
else:
    print("Carpeta localizada en:", BASE_DIR)
    zips = sorted(glob.glob(os.path.join(BASE_DIR, "*.zip")))
    if not zips:
        print("No hay .zip en esa carpeta.")
    else:
        print("ZIPs encontrados:")
        for z in zips:
            print(" -", os.path.basename(z))
        v1 = [z for z in zips if "v4" in os.path.basename(z).lower()]
        SELECTED_ZIP = v1[0] if v1 else zips[0]
        print("\n➡️  Seleccionado para el PASO 1.2:", os.path.basename(SELECTED_ZIP))
# Out:
# ✅ Carpeta localizada en: /content/drive/MyDrive/Colab Notebooks/DATASETS/dataset_1024_resolucion
# ZIPs encontrados:
#  - dataset_arboles_v3.zip
#  - dataset_arboles_v4.zip
#
# ➡️  Seleccionado para el PASO 1.2: dataset_arboles_v4.zip

# %%
# PASO 1.2 — Copiar y descomprimir el ZIP v1 en /content
import os, shutil, zipfile

# Usa la misma variable BASE_DIR del paso anterior
ZIP_V1 = None
for f in os.listdir(BASE_DIR):
    if "v4" in f.lower() and f.endswith(".zip"):
        ZIP_V1 = os.path.join(BASE_DIR, f)
        break

if ZIP_V1 is None:
    raise FileNotFoundError("No encontré un archivo con 'v1' en su nombre dentro de la carpeta del dataset.")

print("📦 Archivo v1 seleccionado:", os.path.basename(ZIP_V1))
# Out:
# 📦 Archivo v1 seleccionado: dataset_arboles_v4.zip

# %%
# Copiar al almacenamiento local de Colab (más rápido)
local_zip = "/content/dataset_v4.zip"
if os.path.exists(local_zip):
    os.remove(local_zip)
shutil.copy2(ZIP_V1, local_zip)
print("✅ Copiado a:", local_zip)
# Out:
# ✅ Copiado a: /content/dataset_v4.zip

# %%
# Descomprimir en carpeta limpia
extract_dir = "/content/dataset_yolov4_l"
if os.path.exists(extract_dir):
    shutil.rmtree(extract_dir)
os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(local_zip, "r") as zf:
    zf.extractall(extract_dir)

print("✅ Descomprimido en:", extract_dir)
print("\nContenido de primer nivel:")
for item in os.listdir(extract_dir):
    p = os.path.join(extract_dir, item)
    print(" - [DIR]" if os.path.isdir(p) else " - [FILE]", item)
# Out:
# ✅ Descomprimido en: /content/dataset_yolov4_l
#
# Contenido de primer nivel:
#  - [DIR] dataset_arboles_v4

# %%
# PASO 2.1 — Detectar la carpeta raíz del dataset descomprimido
import os

EXTRACT_DIR = "/content/dataset_yolov4_l"  # carpeta donde se descomprimió el ZIP

def pick_root(extract_dir):
    """Si solo hay una subcarpeta dentro, entrar en ella; si no, usar extract_dir."""
    items = [i for i in os.listdir(extract_dir) if not i.startswith(".")]
    if len(items) == 1 and os.path.isdir(os.path.join(extract_dir, items[0])):
        return os.path.join(extract_dir, items[0])
    return extract_dir

ROOT = pick_root(EXTRACT_DIR)

print("📁 Raíz detectada:", ROOT)
print("\nContenido dentro de la raíz:")
for i in os.listdir(ROOT):
    print(" -", i)
# Out:
# 📁 Raíz detectada: /content/dataset_yolov4_l/dataset_arboles_v4
#
# Contenido dentro de la raíz:
#  - data.yaml
#  - images
#  - labels

# %%
# PASO 2.2 — Buscar y leer data.yaml (si existe)
import os, glob, yaml

yaml_candidates = []
for pattern in ("*.yaml", "*.yml"):
    yaml_candidates += glob.glob(os.path.join(ROOT, pattern))

if not yaml_candidates:
    print("❌ No se encontró data.yaml ni data.yml en la raíz del dataset.")
else:
    print("✅ Archivos YAML encontrados:")
    for y in yaml_candidates:
        print(" -", os.path.basename(y))

    try:
        # Tomar preferentemente el que se llame data.yaml
        preferred = [y for y in yaml_candidates if "data" in os.path.basename(y).lower()]
        preferred = preferred[0] if preferred else yaml_candidates[0]
        print("\n📄 Leyendo:", os.path.basename(preferred))

        with open(preferred, "r", encoding="utf-8") as f:
            yaml_info = yaml.safe_load(f)

        print("\nContenido del YAML:\n")
        print(yaml_info)
    except Exception as e:
        print("⚠ Error al leer el YAML:", e)
# Out:
# ✅ Archivos YAML encontrados:
#  - data.yaml
#
# 📄 Leyendo: data.yaml
#
# Contenido del YAML:
#
# {'path': '/content/drive/MyDrive/Colab Notebooks/DATASETS/dataset_1024_resolucion/', 'train': 'images/train', 'val': 'images/val', 'test': 'images/test', 'names': {0: 'arbol'}}

# %%
# PASO 2.3 — Detectar estructura YOLO (images/labels por split)
import os

splits = ["train", "val", "test"]
layout = None
paths = {}

# Caso A: images/train y labels/train
if os.path.isdir(os.path.join(ROOT, "images")) and os.path.isdir(os.path.join(ROOT, "labels")):
    layout = "images_split"
    for s in splits:
        paths[s] = {
            "images": os.path.join(ROOT, "images", s),
            "labels": os.path.join(ROOT, "labels", s)
        }

# Caso B: train/images y val/images
if layout is None:
    ok = True
    temp = {}
    for s in splits:
        si = os.path.join(ROOT, s, "images")
        sl = os.path.join(ROOT, s, "labels")
        if not (os.path.isdir(si) and os.path.isdir(sl)):
            ok = False
            break
        temp[s] = {"images": si, "labels": sl}
    if ok:
        layout = "split_images"
        paths = temp

if layout:
    print("✅ Estructura detectada:", layout)
    for s, d in paths.items():
        print(f"\n{s.upper()}:")
        print("  images →", d["images"])
        print("  labels →", d["labels"])
else:
    print("❌ No se detectó estructura YOLO válida.")
# Out:
# ✅ Estructura detectada: images_split
#
# TRAIN:
#   images → /content/dataset_yolov4_l/dataset_arboles_v4/images/train
#   labels → /content/dataset_yolov4_l/dataset_arboles_v4/labels/train
#
# VAL:
#   images → /content/dataset_yolov4_l/dataset_arboles_v4/images/val
#   labels → /content/dataset_yolov4_l/dataset_arboles_v4/labels/val
#
# TEST:
#   images → /content/dataset_yolov4_l/dataset_arboles_v4/images/test
#   labels → /content/dataset_yolov4_l/dataset_arboles_v4/labels/test

# %%
# PASO 2.4 — Conteo de imágenes y etiquetas por split
import os

def count_files(img_dir, lbl_dir):
    imgs = [f for f in os.listdir(img_dir) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
    lbls = [f for f in os.listdir(lbl_dir) if f.lower().endswith('.txt')]
    print(f"  🖼️  Imágenes: {len(imgs)}  |  🏷️  Etiquetas: {len(lbls)}")
    if len(imgs) != len(lbls):
        print("  ⚠️  Diferencia detectada entre número de imágenes y etiquetas.")
        # Mostrar ejemplos de archivos sin pareja
        stem_imgs = {os.path.splitext(f)[0] for f in imgs}
        stem_lbls = {os.path.splitext(f)[0] for f in lbls}
        solo_imgs = sorted(list(stem_imgs - stem_lbls))[:5]
        solo_lbls = sorted(list(stem_lbls - stem_imgs))[:5]
        if solo_imgs:
            print("   - Faltan etiquetas para:", solo_imgs)
        if solo_lbls:
            print("   - Faltan imágenes para:", solo_lbls)
    return len(imgs), len(lbls)

if 'paths' in globals() and paths:
    print("\n=== 📊 RESUMEN POR SPLIT ===")
    for s, d in paths.items():
        print(f"\n[{s.upper()}]")
        if os.path.isdir(d["images"]) and os.path.isdir(d["labels"]):
            count_files(d["images"], d["labels"])
        else:
            print("  ❌ Falta carpeta:", d)
else:
    print("❌ No se detectaron rutas válidas en el paso anterior (2.3).")
# Out:
# === 📊 RESUMEN POR SPLIT ===
#
# [TRAIN]
#   🖼️  Imágenes: 8645  |  🏷️  Etiquetas: 8645
#
# [VAL]
#   🖼️  Imágenes: 2470  |  🏷️  Etiquetas: 2470
#
# [TEST]
#   🖼️  Imágenes: 1235  |  🏷️  Etiquetas: 1235

# %%
# PASO 3.1 — Instalar y verificar YOLOv8 (Ultralytics)
# !pip install ultralytics --upgrade --quiet

from ultralytics import YOLO
import ultralytics

print("✅ Ultralytics instalado correctamente.")
print("Versión:", ultralytics.__version__)

# Verificar GPU disponible
import torch
print("GPU detectada:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "❌ No hay GPU activa")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 71.1 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ Ultralytics instalado correctamente.
# Versión: 8.3.221
# GPU detectada: NVIDIA A100-SXM4-80GB

# %%
# PASO 3.2 — Crear / Ajustar archivo data.yaml
import os, yaml

yaml_path = os.path.join(ROOT, "data.yaml")

# Rutas relativas desde la raíz del dataset
train_path = os.path.relpath(paths["train"]["images"], ROOT)
val_path   = os.path.relpath(paths["val"]["images"], ROOT)
test_path  = os.path.relpath(paths["test"]["images"], ROOT)

# Definir las clases (ajusta si tienes más de una)
data_config = {
    "path": ROOT,
    "train": train_path,
    "val": val_path,
    "test": test_path,
    "names": ["arbol"],  # puedes añadir más clases aquí
}

with open(yaml_path, "w", encoding="utf-8") as f:
    yaml.dump(data_config, f, sort_keys=False, allow_unicode=True)

print("✅ Archivo data.yaml creado correctamente en:", yaml_path)
print("\nContenido del data.yaml:\n")
print(yaml.dump(data_config, sort_keys=False, allow_unicode=True))
# Out:
# ✅ Archivo data.yaml creado correctamente en: /content/dataset_yolov4_l/dataset_arboles_v4/data.yaml
#
# Contenido del data.yaml:
#
# path: /content/dataset_yolov4_l/dataset_arboles_v4
# train: images/train
# val: images/val
# test: images/test
# names:
# - arbol

# %%
# 🔹 Entrenamiento YOLOv8l - Dataset 1024x1024
from ultralytics import YOLO
import os

# Ruta del YAML de tu dataset
yaml_path = os.path.join(ROOT, "data.yaml")

# Crea el modelo (YOLOv8m = versión mediana, mejor precisión que "s")
model = YOLO("yolov8l.pt")

# Entrenamiento
results = model.train(
    data=yaml_path,
    epochs=100,            # puedes subir a 150 si no hay EarlyStopping
    imgsz=1024,            # resolución alta = mejor precisión
    batch=-1,               # ajusta según tu GPU (A100: ok hasta 8)
    device=0,              # usar GPU
    workers=8,
    seed=42,
    project="/content/runs",
    name="yolov8l_1024_precision",

    # Estabilidad y rendimiento
    lr0=0.001,            # LR más bajo para afinar
    cos_lr=True,
    patience=60,
    close_mosaic=15,
    cache=True,           # tienes mucha RAM del sistema, úsala
    hsv_h=0.015, hsv_s=0.7, hsv_v=0.4,
    fliplr=0.5, flipud=0.0,
    degrees=0.0, translate=0.1, scale=0.5, shear=0.0,  # aerial: rotación pequeña

    # Guardado y visualización
    save=True,
    save_period=10,        # checkpoint cada 10 épocas
    plots=True,            # genera PR, F1, confusión, etc.
    val=True               # valida cada epoch quitar el auto u probar con el 0.001, 0.1, 1 elevado a la menos 5: 0.00001

    # optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0004375), 103 bias(decay=0.0)
    # Image sizes 1024 train, 1024 val adams, o otro admax el m por ejemplo.

)

print("\nEntrenamiento lanzado/finalizado.")
print("Carpeta de resultados:", results.save_dir)
print("Pesos mejores (best.pt):", os.path.join(str(results.save_dir), "weights", "best.pt"))
print("Últimos pesos (last.pt):", os.path.join(str(results.save_dir), "weights", "last.pt"))

# no me
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8l.pt to 'yolov8l.pt': 100% ━━━━━━━━━━━━ 83.7MB 251.2MB/s 0.3s
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-80GB, 81222MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=-1, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=15, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/content/dataset_yolov4_l/dataset_arboles_v4/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1024, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8l.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8l_1024_precision, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=60, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/yolov8l_1024_precision, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 119.8MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  3   4461568  ultralytics.nn.modules.block.C2f             [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  16                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   4592640  ultralytics.nn.modules.block.C2f             [768, 512, 3]
#  19                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  22        [15, 18, 21]  1   5583571  ultralytics.nn.modules.head.Detect           [1, [256, 512, 512]]
# Model summary: 209 layers, 43,630,611 parameters, 43,630,595 gradients, 165.4 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 327.1MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3700.1±857.2 MB/s, size: 1166.0 KB)
# train: Scanning /content/dataset_yolov4_l/dataset_arboles_v4/labels/train... 8645 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 8645/8645 147.3it/s 58.7s
# train: New cache created: /content/dataset_yolov4_l/dataset_arboles_v4/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# AutoBatch: Computing optimal batch size for imgsz=1024 at 60.0% CUDA memory utilization.
# AutoBatch: CUDA:0 (NVIDIA A100-SXM4-80GB) 79.32G total, 0.39G reserved, 0.37G allocated, 78.56G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#     43630611       423.4         3.586         84.72         998.6      (1, 3, 1024, 1024)                    list
#     43630611       846.9         5.415         47.74         171.8      (2, 3, 1024, 1024)                    list
#     43630611        1694         8.684         48.76           170      (4, 3, 1024, 1024)                    list
#     43630611        3387        15.085         57.29         179.8      (8, 3, 1024, 1024)                    list
#     43630611        6775        28.150         110.5           242     (16, 3, 1024, 1024)                    list
#     43630611   1.355e+04        52.651         214.9         382.1     (32, 3, 1024, 1024)                    list
# CUDA out of memory. Tried to allocate 512.00 MiB. GPU 0 has a total capacity of 79.32 GiB of which 285.88 MiB is free. Process 8720 has 79.03 GiB memory in use. Of the allocated memory 78.29 GiB is allocated by PyTorch, and 216.80 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# AutoBatch: Using batch-size 28 for CUDA:0 47.37G/79.32G (60%) ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2969.1±1543.9 MB/s, size: 1095.6 KB)
# train: Scanning /content/dataset_yolov4_l/dataset_arboles_v4/labels/train.cache... 8645 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 8645/8645 12.0Mit/s 0.0s
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (25.3GB RAM): 100% ━━━━━━━━━━━━ 8645/8645 165.7it/s 52.2s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2510.4±1171.0 MB/s, size: 1170.1 KB)
# val: Scanning /content/dataset_yolov4_l/dataset_arboles_v4/labels/val... 2470 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2470/2470 140.9it/s 17.5s
# val: New cache created: /content/dataset_yolov4_l/dataset_arboles_v4/labels/val.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (7.2GB RAM): 100% ━━━━━━━━━━━━ 2470/2470 165.8it/s 14.9s
# Plotting labels to /content/runs/yolov8l_1024_precision/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0004375), 103 bias(decay=0.0)
# Image sizes 1024 train, 1024 val
# Using 8 dataloader workers
# Logging results to /content/runs/yolov8l_1024_precision
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      39.8G      2.191      2.346      2.052        301       1024: 100% ━━━━━━━━━━━━ 309/309 1.7it/s 2:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 1.8it/s 24.8s
#                    all       2470      28272      0.444      0.307      0.294     0.0999
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      38.6G       2.04      2.048       1.81        377       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 1.9it/s 23.6s
#                    all       2470      28272      0.494      0.385      0.391      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      38.6G      2.068      2.081      1.827        234       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 1.7it/s 26.6s
#                    all       2470      28272      0.385      0.329      0.279     0.0905
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      38.7G      2.087      2.122      1.845        353       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 1.8it/s 24.5s
#                    all       2470      28272      0.419       0.39      0.343      0.116
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      39.9G      2.062      2.063      1.842        364       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 1.9it/s 23.7s
#                    all       2470      28272      0.422      0.357      0.324      0.106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      37.7G      2.045      2.003      1.821        285       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 1.9it/s 23.9s
#                    all       2470      28272      0.491      0.425      0.415      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      38.8G      2.029      1.966      1.807        369       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 1.9it/s 24.3s
#                    all       2470      28272      0.458      0.387      0.371       0.13
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      40.3G      2.022      1.934      1.797        336       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 1.9it/s 24.0s
#                    all       2470      28272      0.493      0.422       0.42       0.15
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      38.1G      2.005      1.887      1.786        327       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 1.9it/s 23.6s
#                    all       2470      28272      0.521      0.458      0.455      0.167
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      38.1G      1.995      1.858       1.78        317       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 1.9it/s 23.1s
#                    all       2470      28272      0.525      0.438      0.442      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      38.2G      1.983      1.825      1.775        272       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.0it/s 23.0s
#                    all       2470      28272      0.556      0.467      0.483      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      38.2G      1.974      1.796      1.765        358       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 1.9it/s 23
1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.7s
#                    all       2470      28272      0.761      0.678       0.74      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      39.2G      1.042     0.5637      1.149        440       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.9s
#                    all       2470      28272      0.762      0.677       0.74      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      39.2G      1.019     0.5459      1.135        214       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272      0.764      0.677      0.739      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      39.2G      1.015     0.5435      1.132        305       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272       0.76      0.682       0.74      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      39.2G      1.008     0.5412      1.129        399       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272      0.761      0.683      0.741      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      39.2G     0.9949     0.5334      1.126        463       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272      0.764       0.68      0.741      0.434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      39.3G     0.9857     0.5271      1.118        334       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272      0.765       0.68      0.741      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      39.3G     0.9821     0.5239      1.116        341       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272      0.764      0.682      0.741      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      39.3G     0.9803     0.5294       1.12        300       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272       0.76      0.684      0.741      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      39.4G     0.9744      0.523      1.115        325       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272      0.759      0.685      0.741      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      40.3G     0.9609     0.5093      1.105        354       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272      0.762      0.683      0.741      0.439
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      38.4G     0.9828     0.4995      1.142        224       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272       0.76      0.686      0.742      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      38.4G     0.9365     0.4678      1.113        199       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.7s
#                    all       2470      28272      0.759      0.685      0.743      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      38.4G     0.9352     0.4691      1.116        240       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.9s
#                    all       2470      28272      0.757      0.685      0.744      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      39.3G     0.9207     0.4612      1.111        227       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272      0.766      0.678      0.744      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      39.3G     0.9065     0.4496      1.098        220       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.7s
#                    all       2470      28272      0.762      0.681      0.744      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      39.4G     0.8971     0.4459      1.097        259       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.7s
#                    all       2470      28272      0.764       0.68      0.744      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      39.4G     0.9034     0.4515      1.098        180       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.7s
#                    all       2470      28272      0.765      0.679      0.744      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      39.4G     0.8957     0.4468      1.093        244       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272      0.764      0.679      0.744      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      39.5G     0.8809     0.4324      1.084        217       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272      0.764      0.678      0.744      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      39.5G     0.8804     0.4354      1.082        234       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.7s
#                    all       2470      28272      0.768      0.676      0.744      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      39.5G     0.8741     0.4311      1.081        200       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.7s
#                    all       2470      28272      0.772      0.673      0.744      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      39.5G     0.8724     0.4312       1.08        201       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272       0.77      0.676      0.744      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      39.6G     0.8837     0.4402      1.087        187       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.7s
#                    all       2470      28272      0.771      0.675      0.744      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      40.5G     0.8812     0.4381      1.086        206       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272      0.771      0.675      0.744      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      38.6G     0.8712      0.432      1.079        198       1024: 100% ━━━━━━━━━━━━ 309/309 1.8it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 2.1it/s 21.8s
#                    all       2470      28272      0.771      0.675      0.744      0.447
#
# 100 epochs completed in 5.427 hours.
# Optimizer stripped from /content/runs/yolov8l_1024_precision/weights/last.pt, 87.7MB
# Optimizer stripped from /content/runs/yolov8l_1024_precision/weights/best.pt, 87.7MB
#
# Validating /content/runs/yolov8l_1024_precision/weights/best.pt...
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-80GB, 81222MiB)
# Model summary (fused): 112 layers, 43,607,379 parameters, 0 gradients, 164.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 45/45 1.8it/s 24.6s
#                    all       2470      28272      0.771      0.675      0.744      0.447
# Speed: 0.3ms preprocess, 5.5ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /content/runs/yolov8l_1024_precision
#
# ✅ Entrenamiento lanzado/finalizado.
# 📁 Carpeta de resultados: /content/runs/yolov8l_1024_precision
# 🏆 Pesos mejores (best.pt): /content/runs/yolov8l_1024_precision/weights/best.pt
# 🕒 Últimos pesos (last.pt): /content/runs/yolov8l_1024_precision/weights/last.pt

# %%
# !ls -lt /content/runs
# Out:
# total 4
# drwxr-xr-x 3 root root 4096 Oct 26 21:07 yolov8l_1024_precision

# %%
# !cp -r /content/runs/yolov8l_1024_precision /content/drive/MyDrive/yolo_runs_backup_versionL/

# %%
from IPython.display import Image, display
import pandas as pd
import os

# Ruta a tu copia en Drive
run_path = "/content/drive/MyDrive/yolo_runs_backup_versionL"

csv_path = f"{run_path}/results.csv"
df = pd.read_csv(csv_path)

print("Columnas disponibles:", df.columns.tolist(), "\n")
print("Últimas métricas del entrenamiento:")
print(df.tail(3))  #
# Out:
# Columnas disponibles: ['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss', 'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss', 'lr/pg0', 'lr/pg1', 'lr/pg2']
#
# Últimas métricas del entrenamiento:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 97     98  19149.8         0.88368         0.44020         1.08715
# 98     99  19344.4         0.88118         0.43814         1.08611
# 99    100  19537.9         0.87120         0.43203         1.07850
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 97               0.77067            0.67515           0.74398
# 98               0.77109            0.67473           0.74406
# 99               0.77087            0.67501           0.74383
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 97              0.44679       1.58155       0.99003       1.74318  0.000122
# 98              0.44688       1.58121       0.99089       1.74383  0.000110
# 99              0.44705       1.58098       0.99146       1.74461  0.000102
#
#       lr/pg1    lr/pg2
# 97  0.000122  0.000122
# 98  0.000110  0.000110
# 99  0.000102  0.000102

# %%
precision_final = df["metrics/precision(B)"].iloc[-1]
recall_final = df["metrics/recall(B)"].iloc[-1]
map50_final = df["metrics/mAP50(B)"].iloc[-1]
map95_final = df["metrics/mAP50-95(B)"].iloc[-1]

print(f"Precisión final: {precision_final:.3f}")
print(f"Recall final: {recall_final:.3f}")
print(f"mAP@50: {map50_final:.3f}")
print(f"mAP@50-95: {map95_final:.3f}")
# Out:
# Precisión final: 0.771
# Recall final: 0.675
# mAP@50: 0.744
# mAP@50-95: 0.447

# %%
from PIL import Image
from IPython.display import display

# Ruta de una imagen de prueba (puedes cambiarla)
IMG_PATH = "/content/dataset_yolov4_l/dataset_arboles_v4/images/val/DJI_IMG_0211_01_03.png"

# Inferencia
results = model.predict(
    source=IMG_PATH,
    imgsz=1024,     # o 1024 si tu dataset fue 1024x1024
    conf=0.25,     # umbral de confianza
    iou=0.45,      # supresión no máxima
    save=True,     # guarda la imagen anotada
    verbose=False
)

# Mostrar imagen anotada
r = results[0]
annotated = r.plot()[:, :, ::-1]  # BGR -> RGB
display(Image.fromarray(annotated))

# Conteo de detecciones
num_det = len(r.boxes) if r.boxes is not None else 0
print(f"🌿 Árboles detectados: {num_det}")

# Carpeta donde se guardó la imagen resultante
print("Imagen anotada guardada en:", r.save_dir)

# %%
from ultralytics import YOLO

# Ruta al modelo que entrenaste
BEST_PT = "/content/runs/yolov8l_1024_precision/weights/best.pt"

# Cargar el modelo
model = YOLO(BEST_PT)
print("✅ Modelo cargado correctamente:", BEST_PT)
# Out:
# ✅ Modelo cargado correctamente: /content/runs/yolov8l_1024_precision/weights/best.pt
